# %% [markdown]
# # Analyse Fragmenstein results
#
# Fragmenstein places the merges in alignment with the original fragments and minimises the fragment in the protein. Some important metrics and results are output into a json file, including the number of fragments regarded in the merge, the combined RMSD of the merge with the two fragments, and the energy difference between the unbound and bound molecule. This notebook analyses these results.
#
# ## Imports

# %%
import pandas as pd
import os
import pickle
import matplotlib.pyplot as plt
import json

# import scripts
sys.path.insert(1, '/home/sabsr3/xchem/fragment_network_merges/scripts')
from FilterFragmenstein import *

# %% [markdown]
# ## Load original df (before Fragmenstein filtering)

# %%
df = pd.read_csv('/home/sabsr3/xchem/fragment_network_merges/data/filtered/overlapFiltered.csv')
df
# Out:
#             Merge Fragment A ID        Fragment A smiles Fragment B ID  \
# 0    x0107_x0678t         x0107         CC(=O)Nc1cnccc1C         x0678
# 1    x0305_x2569t         x0305         CCNc1ccc(C#N)cn1         x2569
# 2    x0107_x2572t         x0107         CC(=O)Nc1cnccc1C         x2572
# 3    x0434_x2608t         x0434  O=C(Nc1ccccc1)Nc1cccnc1         x2608
# 4    x0434_x2608t         x0434  O=C(Nc1ccccc1)Nc1cccnc1         x2608
# ..            ...           ...                      ...           ...
# 294   x0107_x1382         x0107         CC(=O)Nc1cnccc1C         x1382
# 295   x0107_x1382         x0107         CC(=O)Nc1cnccc1C         x1382
# 296   x0107_x1382         x0107         CC(=O)Nc1cnccc1C         x1382
# 297   x0107_x1382         x0107         CC(=O)Nc1cnccc1C         x1382
# 298   x0107_x1382         x0107         CC(=O)Nc1cnccc1C         x1382
#
#              Fragment B smiles       Synthon  \
# 0              NC(=O)CC1CCCCC1  [Xe]C1CCCCC1
# 1              NC(=O)Cc1cccnc1  [Xe]c1cccnc1
# 2         N#Cc1cccc(CC(N)=O)c1  [Xe]c1ccccc1
# 3            Cc1ccc(NC(N)=O)s1         C[Xe]
# 4            Cc1ccc(NC(N)=O)s1         C[Xe]
# ..                         ...           ...
# 294  CC(NC(=O)CCl)c1cccc(Cl)c1        Cl[Xe]
# 295  CC(NC(=O)CCl)c1cccc(Cl)c1        Cl[Xe]
# 296  CC(NC(=O)CCl)c1cccc(Cl)c1        Cl[Xe]
# 297  CC(NC(=O)CCl)c1cccc(Cl)c1        Cl[Xe]
# 298  CC(NC(=O)CCl)c1cccc(Cl)c1        Cl[Xe]
#
#                                   Smiles Target ID  \
# 0                 Cc1ccncc1NC(C)C1CCCCC1     x0678
# 1           CC(C)(CNC(=O)C(=O)O)c1cccnc1     x2569
# 2              CCOC(=O)c1cnccc1Cc1ccccc1     x2572
# 3              CCC(Nc1cccnc1)c1ccc(C)cc1     x2608
# 4       CC(=CC(=O)c1ccc(C)cc1)NCc1cccnc1     x2608
# ..                                   ...       ...
# 294   Cc1c(Cl)cncc1C(=O)NNC(=O)OC(C)(C)C     x2646
# 295           Cc1c(Cl)cncc1NC(=N)NCC(C)C     x2646
# 296         Cc1c(Cl)cncc1NC(=N)NC(C)(C)C     x2646
# 297        Clc1cnccc1CN1CCCC2(CCCCCC2)C1     x2646
# 298  Cc1ccnc(Cl)c1NCC(C)CNC(=O)OC(C)(C)C     x2646
#
#                      Target smiles  \
# 0          O=C(CC1CCCCC1)Nc1cccnc1
# 1     N#Cc1cncc(CC(=O)Nc2cccnc2)c1
# 2    Cc1ccncc1NC(=O)Cc1cccc(C#N)c1
# 3        Cc1ccc(NC(=O)Nc2cccnc2)s1
# 4        Cc1ccc(NC(=O)Nc2cccnc2)s1
# ..                             ...
# 294   Cc1ccncc1NC(=O)Cc1cccc(Cl)c1
# 295   Cc1ccncc1NC(=O)Cc1cccc(Cl)c1
# 296   Cc1ccncc1NC(=O)Cc1cccc(Cl)c1
# 297   Cc1ccncc1NC(=O)Cc1cccc(Cl)c1
# 298   Cc1ccncc1NC(=O)Cc1cccc(Cl)c1
#
#                                        Fragment A file  \
# 0    /home/sabsr3/xchem/fragment_network_merges/dat...
# 1    /home/sabsr3/xchem/fragment_network_merges/dat...
# 2    /home/sabsr3/xchem/fragment_network_merges/dat...
# 3    /home/sabsr3/xchem/fragment_network_merges/dat...
# 4    /home/sabsr3/xchem/fragment_network_merges/dat...
# ..                                                 ...
# 294  /home/sabsr3/xchem/fragment_network_merges/dat...
# 295  /home/sabsr3/xchem/fragment_network_merges/dat...
# 296  /home/sabsr3/xchem/fragment_network_merges/dat...
# 297  /home/sabsr3/xchem/fragment_network_merges/dat...
# 298  /home/sabsr3/xchem/fragment_network_merges/dat...
#
#                                        Fragment B file  \
# 0    /home/sabsr3/xchem/fragment_network_merges/dat...
# 1    /home/sabsr3/xchem/fragment_network_merges/dat...
# 2    /home/sabsr3/xchem/fragment_network_merges/dat...
# 3    /home/sabsr3/xchem/fragment_network_merges/dat...
# 4    /home/sabsr3/xchem/fragment_network_merges/dat...
# ..                                                 ...
# 294  /home/sabsr3/xchem/fragment_network_merges/dat...
# 295  /home/sabsr3/xchem/fragment_network_merges/dat...
# 296  /home/sabsr3/xchem/fragment_network_merges/dat...
# 297  /home/sabsr3/xchem/fragment_network_merges/dat...
# 298  /home/sabsr3/xchem/fragment_network_merges/dat...
#
#                                               Embedded  \
# 0    <img data-content="rdkit/molecule" src="data:i...
# 1    <img data-content="rdkit/molecule" src="data:i...
# 2    <img data-content="rdkit/molecule" src="data:i...
# 3    <img data-content="rdkit/molecule" src="data:i...
# 4    <img data-content="rdkit/molecule" src="data:i...
# ..                                                 ...
# 294  <img data-content="rdkit/molecule" src="data:i...
# 295  <img data-content="rdkit/molecule" src="data:i...
# 296  <img data-content="rdkit/molecule" src="data:i...
# 297  <img data-content="rdkit/molecule" src="data:i...
# 298  <img data-content="rdkit/molecule" src="data:i...
#
#                                Fragment A protein file  \
# 0    /home/sabsr3/xchem/fragment_network_merges/dat...
# 1    /home/sabsr3/xchem/fragment_network_merges/dat...
# 2    /home/sabsr3/xchem/fragment_network_merges/dat...
# 3    /home/sabsr3/xchem/fragment_network_merges/dat...
# 4    /home/sabsr3/xchem/fragment_network_merges/dat...
# ..                                                 ...
# 294  /home/sabsr3/xchem/fragment_network_merges/dat...
# 295  /home/sabsr3/xchem/fragment_network_merges/dat...
# 296  /home/sabsr3/xchem/fragment_network_merges/dat...
# 297  /home/sabsr3/xchem/fragment_network_merges/dat...
# 298  /home/sabsr3/xchem/fragment_network_merges/dat...
#
#                                Fragment B protein file
# 0    /home/sabsr3/xchem/fragment_network_merges/dat...
# 1    /home/sabsr3/xchem/fragment_network_merges/dat...
# 2    /home/sabsr3/xchem/fragment_network_merges/dat...
# 3    /home/sabsr3/xchem/fragment_network_merges/dat...
# 4    /home/sabsr3/xchem/fragment_network_merges/dat...
# ..                                                 ...
# 294  /home/sabsr3/xchem/fragment_network_merges/dat...
# 295  /home/sabsr3/xchem/fragment_network_merges/dat...
# 296  /home/sabsr3/xchem/fragment_network_merges/dat...
# 297  /home/sabsr3/xchem/fragment_network_merges/dat...
# 298  /home/sabsr3/xchem/fragment_network_merges/dat...
#
# [299 rows x 14 columns]

# %% [markdown]
# ## Get the data from the json files

# %%
# G_bound is : data['Energy']['ligand_ref2015']['total_score']
# G_unbound is : data['Energy']['unbound_ref2015']['total_score']
# the combined RMSD is data['mRMSD']
# data['RMSDs'] - find values not equal to None to get number regarded

all_data = {}

for folder in os.listdir('/home/sabsr3/xchem/Fragmenstein/output/filtered'):
    path = os.path.join('/home/sabsr3/xchem/Fragmenstein/output/filtered', folder)
    for f in os.listdir(path):
        if 'minimised.json' in f:
            d = {}
            json_path = os.path.join(path, f)
            json_file = open(json_path)
            data = json.load(json_file)
            d['G_bound'] = data['Energy']['ligand_ref2015']['total_score']
            d['G_unbound'] = data['Energy']['unbound_ref2015']['total_score']
            d['comRMSD'] = data['mRMSD']
            regarded = 0
            for rmsd in data['RMSDs']:
                if rmsd != None:
                    regarded += 1
            d['regarded'] = regarded
            name = f.replace('.minimised.json', '')
            all_data[name] = d

# %% [markdown]
# ## Plot the data

# %%
deltaGs = []
regarded = []
comRMSDs = []

for merge in all_data:
    deltaG = all_data[merge]['G_bound'] - all_data[merge]['G_unbound']
    deltaGs.append(deltaG)
    regarded.append(all_data[merge]['regarded'])
    comRMSDs.append(all_data[merge]['comRMSD'])

# %%
plt.figure(figsize=(14,10))
plt.hist(comRMSDs)
plt.title('RMSD between placed merge and fragments', fontsize=15)
plt.xlabel('combined RMSD', fontsize=15)
plt.ylabel('Frequency', fontsize=15)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.show()

# %%
plt.figure(figsize=(14,10))
plt.hist(deltaGs)
plt.title('∆∆G: : difference in energy relative to unbound molecule', fontsize=15)
plt.xlabel('deltaG', fontsize=15)
plt.ylabel('Frequency', fontsize=15)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.show()

# %%
plt.figure(figsize=(14,10))
plt.scatter(deltaGs, comRMSDs)
plt.title('∆∆G against comRMSD of placed merges', fontsize=15)
plt.xlabel('deltaG', fontsize=15)
plt.ylabel('combined RMSD', fontsize=15)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.show()

# %% [markdown]
# ## Plot the data after filtering for molecules where both fragments were considered in the placement/minimisation

# %%
filtered = []

for i, r in enumerate(regarded):
    if r == 2:
        filtered.append(i)

# %%
plt.figure(figsize=(14,10))
plt.hist([comRMSDs[i] for i in filtered])
plt.title('RMSD between placed merge and fragments: 2 fragments regarded', fontsize=15)
plt.xlabel('combined RMSD', fontsize=15)
plt.ylabel('Frequency', fontsize=15)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.show()

# %%
plt.figure(figsize=(14,10))
plt.hist([deltaGs[i] for i in filtered])
plt.title('∆∆G: : difference in energy relative to unbound molecule: 2 fragments regarded', fontsize=15)
plt.xlabel('deltaG', fontsize=15)
plt.ylabel('Frequency', fontsize=15)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.show()

# %%
plt.figure(figsize=(14,10))
plt.scatter([deltaGs[i] for i in filtered], [comRMSDs[i] for i in filtered])
plt.title('∆∆G against comRMSD of placed merges: 2 fragments regarded', fontsize=15)
plt.xlabel('deltaG', fontsize=15)
plt.ylabel('combined RMSD', fontsize=15)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.show()

# %% [markdown]
# ## Count the number of compounds that would fulfill some criteria
#
# 2 fragments regarded, negative delta G and comRMSD above 1 or 1.5 A

# %%
count = 0

for r, dG, rmsd in zip(regarded, deltaGs, comRMSDs):
    if r == 2:
        if dG < 0:
            if rmsd < 1.5:
                count += 1

print('Number of compounds with negative deltaG and comRMSD <1.5A:', count)
# Out:
# Number of compounds with negative deltaG and comRMSD <1.5A: 74

# %%
count = 0

for r, dG, rmsd in zip(regarded, deltaGs, comRMSDs):
    if r == 2:
        if dG < 0:
            if rmsd < 1:
                count += 1

print('Number of compounds with negative deltaG and comRMSD <1A:', count)
# Out:
# Number of compounds with negative deltaG and comRMSD <1A: 50

# %% [markdown]
# Filter the results in the df

# %%
lst = []

for folder in os.listdir('/home/sabsr3/xchem/Fragmenstein/output/filtered'):
    path = os.path.join('/home/sabsr3/xchem/Fragmenstein/output/filtered', folder)
    for f in os.listdir(path):
        if 'minimised.json' in f:
            json_path = os.path.join(path, f)
            lst.append(FragFilter(json_path).filter())

# %%
filtered = [i for i in lst if i != None]
print('Number of compounds: ', len(filtered))
# Out:
# Number of compounds:  74

# %%
filtered[0].split('/')[7].split('-')[2]
# Out:
# '53'

# %%
def get_indices(fnames):
    indices = []
    for fname in fnames:
        indices.append(fname.split('/')[7].split('-')[2])
    return indices

# %%
indices = get_indices(filtered)

# %%
new_df = df[df.index.isin(indices)]

# %%
new_df
# Out:
#             Merge Fragment A ID        Fragment A smiles Fragment B ID  \
# 0    x0107_x0678t         x0107         CC(=O)Nc1cnccc1C         x0678
# 11   x0434_x2608t         x0434  O=C(Nc1ccccc1)Nc1cccnc1         x2608
# 15   x0434_x2608t         x0434  O=C(Nc1ccccc1)Nc1cccnc1         x2608
# 17   x0434_x2608t         x0434  O=C(Nc1ccccc1)Nc1cccnc1         x2608
# 20   x0434_x2608t         x0434  O=C(Nc1ccccc1)Nc1cccnc1         x2608
# ..            ...           ...                      ...           ...
# 235  x0107_x2908t         x0107         CC(=O)Nc1cnccc1C         x2908
# 237  x0107_x2908t         x0107         CC(=O)Nc1cnccc1C         x2908
# 238  x0107_x2908t         x0107         CC(=O)Nc1cnccc1C         x2908
# 268   x0678_x1249         x0678  O=C(CC1CCCCC1)Nc1cccnc1         x1249
# 269   x0678_x1249         x0678  O=C(CC1CCCCC1)Nc1cccnc1         x1249
#
#                 Fragment B smiles       Synthon  \
# 0                 NC(=O)CC1CCCCC1  [Xe]C1CCCCC1
# 11              Cc1ccc(NC(N)=O)s1         C[Xe]
# 15              Cc1ccc(NC(N)=O)s1         C[Xe]
# 17              Cc1ccc(NC(N)=O)s1         C[Xe]
# 20              Cc1ccc(NC(N)=O)s1         C[Xe]
# ..                            ...           ...
# 235           NC(=O)Nc1cccc(Cl)c1        Cl[Xe]
# 237           NC(=O)Nc1cccc(Cl)c1        Cl[Xe]
# 238           NC(=O)Nc1cccc(Cl)c1        Cl[Xe]
# 268  N#Cc1ccc(CNC(=O)N2CCOCC2)cc1       N#C[Xe]
# 269  N#Cc1ccc(CNC(=O)N2CCOCC2)cc1       N#C[Xe]
#
#                                    Smiles Target ID  \
# 0                  Cc1ccncc1NC(C)C1CCCCC1     x0678
# 11   COC(Cc1ccccc1)CS(=O)(=O)Nc1ccc(C)cn1     x2608
# 15    CC(=O)N(CCc1ccccc1)CC(=O)Nc1cnccc1C     x2608
# 17               CC1COCCC1NC(=O)Nc1cccnc1     x2608
# 20             CC1CC(NC(=O)Nc2cccnc2)CCO1     x2608
# ..                                    ...       ...
# 235       Cc1ccnc(Cl)c1NS(=O)(=O)CCC(=O)O     x2908
# 237     Cc1ccnc(Cl)c1NS(=O)(=O)C(C)C(=O)O     x2908
# 238   Cc1ccnc(Cl)c1NCC(C)CNC(=O)OC(C)(C)C     x2908
# 268           N#Cc1cccnc1SCC(=O)NC1CCCCC1     x2600
# 269               N#CC1CCCC(CCc2ccccn2)C1     x2600
#
#                     Target smiles  \
# 0         O=C(CC1CCCCC1)Nc1cccnc1
# 11      Cc1ccc(NC(=O)Nc2cccnc2)s1
# 15      Cc1ccc(NC(=O)Nc2cccnc2)s1
# 17      Cc1ccc(NC(=O)Nc2cccnc2)s1
# 20      Cc1ccc(NC(=O)Nc2cccnc2)s1
# ..                            ...
# 235  Cc1ccncc1NC(=O)Nc1cccc(Cl)c1
# 237  Cc1ccncc1NC(=O)Nc1cccc(Cl)c1
# 238  Cc1ccncc1NC(=O)Nc1cccc(Cl)c1
# 268  N#Cc1cccc(CC(=O)Nc2cccnc2)c1
# 269  N#Cc1cccc(CC(=O)Nc2cccnc2)c1
#
#                                        Fragment A file  \
# 0    /home/sabsr3/xchem/fragment_network_merges/dat...
# 11   /home/sabsr3/xchem/fragment_network_merges/dat...
# 15   /home/sabsr3/xchem/fragment_network_merges/dat...
# 17   /home/sabsr3/xchem/fragment_network_merges/dat...
# 20   /home/sabsr3/xchem/fragment_network_merges/dat...
# ..                                                 ...
# 235  /home/sabsr3/xchem/fragment_network_merges/dat...
# 237  /home/sabsr3/xchem/fragment_network_merges/dat...
# 238  /home/sabsr3/xchem/fragment_network_merges/dat...
# 268  /home/sabsr3/xchem/fragment_network_merges/dat...
# 269  /home/sabsr3/xchem/fragment_network_merges/dat...
#
#                                        Fragment B file  \
# 0    /home/sabsr3/xchem/fragment_network_merges/dat...
# 11   /home/sabsr3/xchem/fragment_network_merges/dat...
# 15   /home/sabsr3/xchem/fragment_network_merges/dat...
# 17   /home/sabsr3/xchem/fragment_network_merges/dat...
# 20   /home/sabsr3/xchem/fragment_network_merges/dat...
# ..                                                 ...
# 235  /home/sabsr3/xchem/fragment_network_merges/dat...
# 237  /home/sabsr3/xchem/fragment_network_merges/dat...
# 238  /home/sabsr3/xchem/fragment_network_merges/dat...
# 268  /home/sabsr3/xchem/fragment_network_merges/dat...
# 269  /home/sabsr3/xchem/fragment_network_merges/dat...
#
#                                               Embedded  \
# 0    <img data-content="rdkit/molecule" src="data:i...
# 11   <img data-content="rdkit/molecule" src="data:i...
# 15   <img data-content="rdkit/molecule" src="data:i...
# 17   <img data-content="rdkit/molecule" src="data:i...
# 20   <img data-content="rdkit/molecule" src="data:i...
# ..                                                 ...
# 235  <img data-content="rdkit/molecule" src="data:i...
# 237  <img data-content="rdkit/molecule" src="data:i...
# 238  <img data-content="rdkit/molecule" src="data:i...
# 268  <img data-content="rdkit/molecule" src="data:i...
# 269  <img data-content="rdkit/molecule" src="data:i...
#
#                                Fragment A protein file  \
# 0    /home/sabsr3/xchem/fragment_network_merges/dat...
# 11   /home/sabsr3/xchem/fragment_network_merges/dat...
# 15   /home/sabsr3/xchem/fragment_network_merges/dat...
# 17   /home/sabsr3/xchem/fragment_network_merges/dat...
# 20   /home/sabsr3/xchem/fragment_network_merges/dat...
# ..                                                 ...
# 235  /home/sabsr3/xchem/fragment_network_merges/dat...
# 237  /home/sabsr3/xchem/fragment_network_merges/dat...
# 238  /home/sabsr3/xchem/fragment_network_merges/dat...
# 268  /home/sabsr3/xchem/fragment_network_merges/dat...
# 269  /home/sabsr3/xchem/fragment_network_merges/dat...
#
#                                Fragment B protein file
# 0    /home/sabsr3/xchem/fragment_network_merges/dat...
# 11   /home/sabsr3/xchem/fragment_network_merges/dat...
# 15   /home/sabsr3/xchem/fragment_network_merges/dat...
# 17   /home/sabsr3/xchem/fragment_network_merges/dat...
# 20   /home/sabsr3/xchem/fragment_network_merges/dat...
# ..                                                 ...
# 235  /home/sabsr3/xchem/fragment_network_merges/dat...
# 237  /home/sabsr3/xchem/fragment_network_merges/dat...
# 238  /home/sabsr3/xchem/fragment_network_merges/dat...
# 268  /home/sabsr3/xchem/fragment_network_merges/dat...
# 269  /home/sabsr3/xchem/fragment_network_merges/dat...
#
# [74 rows x 14 columns]

# %% [markdown]
# ### Save to csv

# %%
new_df.to_csv('/home/sabsr3/xchem/fragment_network_merges/data/filtered/fragmensteinFiltered.csv')
